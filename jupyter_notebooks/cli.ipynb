# %% [markdown]
# # Python package for OPUS-Seti API (NASA-PDS Rings Node) - CLI
#
# The `opus-seti` python package can be use directly in `python` (see [examples](https://nbviewer.jupyter.org/github/seignovert/python-opus-seti/blob/master/jupyter_notebooks/examples.ipynb)) but some the API can be called directly from the command line.
#
# Here is an examples of the few command line availables:
# - `opus`: Get data (global search)
# - `opus-meta`: Get detail for a single observation
# - `opus-preview`: Get image preview for a single observation
# - `opus-files`: Get files for a single observation
# - `opus-field`: Get information about field
#
# - `cassini-vims` Get data (shortcut to search only in the Cassini VIMS data)
#
# (__Note:__ To reproduce the examples, remove the initial `!` in the following lines.)

# %% [markdown]
# ## Getting data

# %%
# To get help on the main `opus` function:
# !opus -h
# Out:
# usage: opus [-h] [-a] [-l LIMIT] [-p PAGE] [--field VALUE]
#
# Get Data from OPUS-SETI API
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a, --all             Get all the output at once (disable: --limit/--page)
#   -l LIMIT, --limit LIMIT
#                         Output limits (default: 10)
#   -p PAGE, --page PAGE  Page offset (default: 1)
#   --field VALUE         Field key and value (sep. ` ` or `=`)

# %%
# Global OPUS query on the API:
# !opus -l 5 -p 2 --instrumentid='Cassini+VIMS' --surfacegeometrytargetname TITAN
# Out:
# OPUS API Data objects (with 5 elements):
#  - COVIMS_0004-2004143T032617_2004143T075833-v1463897465_1_IR
#  - COVIMS_0004-2004143T032617_2004143T075833-v1463897481_1_IR
#  - COVIMS_0004-2004143T032617_2004143T075833-v1463897514_1_IR
#  - COVIMS_0004-2004143T032617_2004143T075833-v1463897558_1_VIS
#  - COVIMS_0004-2004143T032617_2004143T075833-v1463905293_1_IR

# %% [markdown]
# ## Metadata

# %%
# Get the metada for a single observation:
# !opus-meta COVIMS_0004-2004143T032617_2004143T075833-v1463897465_1_IR
# Out:
# OPUS API Metadata Ring observation: COVIMS_0004-2004143T032617_2004143T075833-v1463897465_1_IR
#
# => GENERAL constraints
#  - planet: Saturn
#  - target: Titan
#  - targetclass: Regular Satellite
#  - mission: Cassini
#  - insthost: Cassini
#  - instrument: Cassini VIMS
#  - time1: 2004-05-22 05:47:13.148000
#  - time2: 2004-05-22 05:47:16.871000
#  - timesec1: 138520065.148
#  - timesec2: 138520068.871
#  - observationduration: 3.7229999899864197
#  - spatialsampling: 2-D
#  - wavelengthsampling: Yes
#  - quantity: Reflectivity
#  - rightasc1: 33.63538
#  - rightasc2: 33.820161
#  - declination1: 9.525119
#  - declination2: 9.707303
#  - opusid: COVIMS_0004-2004143T032617_2004143T075833-v1463897465_1_IR
#  - ringobsid: S_CUBE_CO_VIMS_1463897465_IR
#
# => PDS constraints
#  - volumeid: COVIMS_0004
#  - datasetid: CO-E/V/J/S-VIMS-2-QUBE-V1.0
#  - productid: 1/1463897465_1
#  - productcreationtime: 2018-04-26 16:00:00
#  - productcreationtimesec: 578073637.0
#  - primaryfilespec: COVIMS_0004/data/2004143T032617_2004143T075833/v1463897465_1.qub
#
# => IMAGE constraints
#  - duration: 0.08
#  - greaterpixelsize: 6
#  - lesserpixelsize: 6
#  - levels: 4096
#  - imagetype: Raster Scan
#
# => WAVELENGTH constraints
#  - wavelength1: 0.8842
#  - wavelength2: 5.1225
#  - waveres1: 0.01662
#  - waveres2: 0.01662
#  - waveno1: 1952.1717911176186
#  - waveno2: 11309.658448314862
#  - wavenores1: 6.3338399547827855
#  - wavenores2: 212.583717949551
#  - specflag: Yes
#  - specsize: 256
#  - polarizationtype: None
#
# => SATURN_SURFACE_GEOMETRY constraints
#  - SURFACEGEOsaturnsubsolarplanetographiclatitude: -29.542
#  - SURFACEGEOsaturnsubobserverplanetographiclatitude: -19.825
#  - SURFACEGEOsaturnsubsolarplanetocentriclatitude: -24.756
#  - SURFACEGEOsaturnsubobserverplanetocentriclatitude: -16.349
#  - SURFACEGEOsaturnsubsolarIAUlongitude: 133.328
#  - SURFACEGEOsaturnsubobserverIAUlongitude: 205.483
#  - SURFACEGEOsaturncenterdistance: 21381752.903
#  - SURFACEGEOsaturncenterresolution: 10584.0
#  - SURFACEGEOsaturncenterphaseangle: 67.362
#
# => TITAN_SURFACE_GEOMETRY constraints
#  - SURFACEGEOtitansubsolarplanetographiclatitude: -24.697
#  - SURFACEGEOtitansubobserverplanetographiclatitude: -16.192
#  - SURFACEGEOtitansubsolarplanetocentriclatitude: -24.697
#  - SURFACEGEOtitansubobserverplanetocentriclatitude: -16.192
#  - SURFACEGEOtitansubsolarIAUlongitude: 212.25
#  - SURFACEGEOtitansubobserverIAUlongitude: 287.551
#  - SURFACEGEOtitancenterdistance: 21719257.922
#  - SURFACEGEOtitancenterresolution: 10751.0
#  - SURFACEGEOtitancenterphaseangle: 70.251
#
# => RING_GEOMETRY constraints
#  - RINGGEOringradius1: 1153980.507
#  - RINGGEOringradius2: 1277926.647
#  - RINGGEOJ2000longitude1: 320.344
#  - RINGGEOJ2000longitude2: 330.841
#  - RINGGEOsubsolarringlong: 288.835
#  - RINGGEOsolarhourangle1: 211.51
#  - RINGGEOsolarhourangle2: 222.006
#  - RINGGEOsubobserverringlong: 216.679
#  - RINGGEOlongitudeWRTobserver1: 103.665
#  - RINGGEOlongitudeWRTobserver2: 114.162
#  - RINGGEOringazimuthWRTobserver1: 106.752
#  - RINGGEOringazimuthWRTobserver2: 117.333
#  - RINGGEOrangetoringintercept1: 21672525.885
#  - RINGGEOringcenterdistance: 21381752.903
#  - RINGGEOrangetoringintercept2: 21915249.788
#  - RINGGEOresolution1: 10728.0
#  - RINGGEOresolution2: 10848.0
#  - RINGGEOprojectedradialresolution1: 15150.0
#  - RINGGEOprojectedradialresolution2: 20539.0
#  - RINGGEOphase1: 70.179
#  - RINGGEOphase2: 70.325
#  - RINGGEOincidence1: 65.225
#  - RINGGEOincidence2: 65.227
#  - RINGGEOemission1: 73.877
#  - RINGGEOemission2: 74.06
#  - RINGGEOnorthbasedincidence1: 114.773
#  - RINGGEOnorthbasedincidence2: 114.775
#  - RINGGEOnorthbasedemission1: 105.94
#  - RINGGEOnorthbasedemission2: 106.123
#  - RINGGEOsolarringelev1: -24.775
#  - RINGGEOsolarringelev2: -24.773
#  - RINGGEOobserverringelevation1: -16.123
#  - RINGGEOobserverringelevation2: -15.94
#  - RINGGEOringcenterphase: 67.362
#  - RINGGEOringcenterincidence: 65.244
#  - RINGGEOringcenteremission: 73.652
#  - RINGGEOringcenternorthbasedincidence: 114.756
#  - RINGGEOringcenternorthbasedemission: 106.348
#  - RINGGEOsolarringopeningangle: -24.756
#  - RINGGEOobserverringopeningangle: -16.349
#  - RINGGEOedgeonradius1: 1086035.22
#  - RINGGEOedgeonradius2: 1154240.234
#  - RINGGEOedgeonJ2000longitude1: 303.454
#  - RINGGEOedgeonJ2000longitude2: 303.644
#  - RINGGEOedgeonsolarhourangle1: 194.619
#  - RINGGEOedgeonsolarhourangle2: 194.81
#  - RINGGEOrangetoedgeonpoint1: 21304968.393
#  - RINGGEOrangetoedgeonpoint2: 21326265.712
#  - RINGGEOedgeonradialresolution1: 10546.0
#  - RINGGEOedgeonradialresolution2: 10556.0
#  - RINGGEOedgeonaltitude1: -167595.887
#  - RINGGEOedgeonaltitude2: -96155.077
#
# => CASSINI_MISSION constraints
#  - CASSINIobsname: VIMS_000TI_LIGHTC066
#  - CASSINIactivityname: LIGHTC
#  - CASSINImissionphasename: Approach Science
#  - CASSINItargetcode: TI (Titan)
#  - CASSINIrevno: 000
#  - CASSINIrevnoint: -1
#  - CASSINIprimeinst: VIMS
#  - CASSINIisprime: Yes
#  - CASSINIsequenceid: S01
#  - CASSINIspacecraftclockcount1: 1/1463897465.223
#  - CASSINIspacecraftclockcount2: 1/1463897469.152
#  - CASSINIspacecraftclockcountdec1: 1463897465.8710938
#  - CASSINIspacecraftclockcountdec2: 1463897469.59375
#
# => CASSINI_VIMS constraints
#  - COVIMSchannel: IR
#  - COVIMSvissamplingmode: Normal
#  - COVIMSvisexposure: 480.0
#  - COVIMSirsamplingmode: Normal
#  - COVIMSirexposure: 80.0
#  - COVIMSswathwidth: 6
#  - COVIMSswathlength: 6
#  - COVIMSspectralsumming: No
#  - COVIMSspectralediting: No
#  - COVIMSinstrumentmode: IMAGE
#  - COVIMSstartracking: Off

# %% [markdown]
# ## Image previews

# %%
# Get the image preview for a single observation:
# !opus-preview -h
# Out:
# usage: opus-preview [-h] [-s {thumb,small,med,full}] [-d] [-o OUTPUT] opus_id
#
# Get image for a single observation from OPUS-SETI API
#
# positional arguments:
#   opus_id               Valid opus_id
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -s {thumb,small,med,full}, --size {thumb,small,med,full}
#                         Image size
#   -d, --download        Download the image
#   -o OUTPUT, --output OUTPUT
#                         Output folder/filename for download

# %%
# Ex: get preview url location:
# !opus-preview COISS_2001-1459551663_1459568594-N1459551972_1 -s med
# Out:
# https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_med.jpg

# %%
# Ex: download preview:
# !opus-preview COISS_2001-1459551663_1459568594-N1459551972_1 -o ../tests/data/
# Out:
# ../tests/data/N1459551972_1_med.jpg

# %% [markdown]
# ## Image files

# %%
# Get files for a single observation:
# !opus-files -h
# Out:
# usage: opus-files [-h] [-f GROUP FORMAT] [-d] [-o OUTPUT] opus_id
#
# Get files for a single observation from OPUS-SETI API
#
# positional arguments:
#   opus_id               Valid opus_id
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f GROUP FORMAT, --fmt GROUP FORMAT
#                         File format
#   -d, --download        Download the image
#   -o OUTPUT, --output OUTPUT
#                         Output folder/filename for download

# %%
# Ex: get file url location:
# !opus-files COISS_2001-1459551663_1459568594-N1459551972_1
# Out:
# OPUS API Files for observation: COISS_2001-1459551663_1459568594-N1459551972_1
#
# => FULL-SIZE
#  - full: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_full.jpg
#
# => MEDIUM
#  - med: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_med.jpg
#
# => SMALL
#  - small: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_small.jpg
#
# => THUMBNAIL
#  - thumb: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_thumb.jpg
#
# => CALIBRATED_DATA
#  - IMG: https://pds-rings.seti.org/holdings/calibrated/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_CALIB.IMG
#  - LBL: https://pds-rings.seti.org/holdings/calibrated/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_CALIB.LBL
#
# => PLANET_GEOMETRY_INDEX
#  - TAB: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_saturn_summary.tab
#  - LBL: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_saturn_summary.lbl
#
# => RAW_DATA
#  - IMG: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1.IMG
#  - LBL: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1.LBL
#  - prefix2: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/label/prefix2.fmt
#  - tlmtab: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/label/tlmtab.fmt
#
# => RING_GEOMETRY_INDEX
#  - TAB: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_ring_summary.tab
#  - LBL: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_ring_summary.lbl
#
# => SATELLITE_GEOMETRY_INDEX
#  - TAB: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_moon_summary.tab
#  - LBL: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_moon_summary.lbl
#
# => TARGET_BODY_INVENTORY
#  - TAB: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_inventory.tab
#  - LBL: https://pds-rings.seti.org/holdings/metadata/COISS_2xxx/COISS_2001/COISS_2001_inventory.lbl

# %%
# Ex: download raw label file:
# !opus-files COISS_2001-1459551663_1459568594-N1459551972_1 -f RAW_DATA LBL -o ../tests/data/
# Out:
# ../tests/data/N1459551972_1.LBL

# %% [markdown]
# ## Getting information about fields

# %%
## Search for a known field
# !opus-field target
# Out:
# Intended Target Name

# %%
# Get all the available fields/targets:
# !opus-field --all
# Out:
# OPUS API list of all fields available (247):
#  - planet
#  - target
#  - targetclass
#  - mission
#  - insthost
#  - instrument
#  - time1
#  - time2
#  - timesec1
#  - timesec2
#  - observationduration
#  - spatialsampling
#  - wavelengthsampling
#  - timesampling
#  - quantity
#  - rightasc1
#  - rightasc2
#  - declination1
#  - declination2
#  - opusid
#  - ringobsid
#  - cocirsdetectorid
#  - cocirsinstrumentmodeallflag
#  - cocirsinstrumentmodeblinkingflag
#  - cocirsinstrumentmodeevenflag
#  - cocirsinstrumentmodeoddflag
#  - cocirsinstrumentmodecentersflag
#  - cocirsinstrumentmodepairsflag
#  - coisscamera
#  - coissfilter
#  - coissshuttermode
#  - coissshutterstate
#  - coisscompressiontype
#  - coissdataconversiontype
#  - coissgainmode
#  - coissinstrumentmode
#  - coissmissinglines
#  - coissimagenumber
#  - coisstargetdesc
#  - coissimageobservationtype
#  - couvischannel
#  - couvisobservationtype
#  - couvisoccultationportstate
#  - couvisslitstate
#  - couvisline1
#  - couvisline2
#  - couvislinebin
#  - couvisband1
#  - couvisband2
#  - couvisbandbin
#  - couvissamples
#  - couviscompressiontype
#  - couvisintegrationduration
#  - couvisdwelltime
#  - couvistestpulsestate
#  - covimschannel
#  - covimsvissamplingmode
#  - covimsvisexposure
#  - covimsirsamplingmode
#  - covimsirexposure
#  - covimsswathwidth
#  - covimsswathlength
#  - covimsspectralsumming
#  - covimsspectralediting
#  - covimsinstrumentmode
#  - covimsstartracking
#  - gossifilter
#  - gossifilternumber
#  - gossicompressiontype
#  - gossigainmode
#  - gossiobstruction
#  - gossiframeduration
#  - gossiimageid
#  - gossiobservationid
#  - nhlorribinningmode
#  - nhlorriinstrumentcompressiontype
#  - nhmvicinstrumentcompressiontype
#  - vgisscamera
#  - vgissfilter
#  - vgissfilternumber
#  - vgissshuttermode
#  - vgisseditmode
#  - vgissgainmode
#  - vgissscanmode
#  - vgissimageid
#  - vgissusablelines
#  - vgissusablesamples
#  - cassiniobsname
#  - cassiniactivityname
#  - cassinimissionphasename
#  - cassinitargetcode
#  - cassinirevno
#  - cassinirevnoint
#  - cassiniprimeinst
#  - cassiniisprime
#  - cassinisequenceid
#  - cassinispacecraftclockcount1
#  - cassinispacecraftclockcount2
#  - cassinispacecraftclockcountdec1
#  - cassinispacecraftclockcountdec2
#  - cassiniert1
#  - cassiniert2
#  - cassiniertsec1
#  - cassiniertsec2
#  - galileoorbitnumber
#  - galileospacecraftclockcount1
#  - galileospacecraftclockcount2
#  - galileospacecraftclockcountdec1
#  - galileospacecraftclockcountdec2
#  - hstdetector
#  - hstfilter
#  - hstfiltertype
#  - hstaperturetype
#  - hstproposalid
#  - hstpiname
#  - hststscigroupid
#  - hsttargetname
#  - hsttargeteddetector
#  - hstpc1flag
#  - hstwf2flag
#  - hstwf3flag
#  - hstwf4flag
#  - hstexposuretype
#  - hstfineguidancesystemlocktype
#  - hstgainmode
#  - hstinstrumentmode
#  - hstpublicationdate
#  - hstpublicationdatesec
#  - newhorizonsmissionphase
#  - newhorizonsspacecraftclockcount1
#  - newhorizonsspacecraftclockcount2
#  - newhorizonsspacecraftclockcountdec1
#  - newhorizonsspacecraftclockcountdec2
#  - voyagermissionphasename
#  - voyagerspacecraftclockcount1
#  - voyagerspacecraftclockcount2
#  - voyagerspacecraftclockcountdec1
#  - voyagerspacecraftclockcountdec2
#  - voyagerert
#  - voyagerertsec
#  - volumeid
#  - datasetid
#  - productid
#  - productcreationtime
#  - productcreationtimesec
#  - primaryfilespec
#  - note
#  - ringgeorangetoringintercept1
#  - ringgeoringcenterdistance
#  - ringgeorangetoringintercept2
#  - ringgeoresolution1
#  - ringgeoresolution2
#  - ringgeoprojectedradialresolution1
#  - ringgeoprojectedradialresolution2
#  - ringgeoedgeonradius1
#  - ringgeoedgeonradius2
#  - ringgeoedgeonj2000longitude1
#  - ringgeoedgeonj2000longitude2
#  - ringgeoedgeonsolarhourangle1
#  - ringgeoedgeonsolarhourangle2
#  - ringgeorangetoedgeonpoint1
#  - ringgeorangetoedgeonpoint2
#  - ringgeoedgeonradialresolution1
#  - ringgeoedgeonradialresolution2
#  - ringgeoedgeonaltitude1
#  - ringgeoedgeonaltitude2
#  - ringgeophase1
#  - ringgeophase2
#  - ringgeoincidence1
#  - ringgeoincidence2
#  - ringgeoemission1
#  - ringgeoemission2
#  - ringgeonorthbasedincidence1
#  - ringgeonorthbasedincidence2
#  - ringgeonorthbasedemission1
#  - ringgeonorthbasedemission2
#  - ringgeosolarringelev1
#  - ringgeosolarringelev2
#  - ringgeoobserverringelevation1
#  - ringgeoobserverringelevation2
#  - ringgeoringcenterphase
#  - ringgeoringcenterincidence
#  - ringgeoringcenteremission
#  - ringgeoringcenternorthbasedincidence
#  - ringgeoringcenternorthbasedemission
#  - ringgeosolarringopeningangle
#  - ringgeoobserverringopeningangle
#  - ringgeoringradius1
#  - ringgeoringradius2
#  - ringgeoj2000longitude1
#  - ringgeoj2000longitude2
#  - ringgeosubsolarringlong
#  - ringgeosolarhourangle1
#  - ringgeosolarhourangle2
#  - ringgeosubobserverringlong
#  - ringgeolongitudewrtobserver1
#  - ringgeolongitudewrtobserver2
#  - ringgeoringazimuthwrtobserver1
#  - ringgeoringazimuthwrtobserver2
#  - surfacegeometrytargetname
#  - surfacegeo<target>rangetobody1
#  - surfacegeo<target>rangetobody2
#  - surfacegeo<target>centerdistance
#  - surfacegeo<target>finestresolution1
#  - surfacegeo<target>finestresolution2
#  - surfacegeo<target>coarsestresolution1
#  - surfacegeo<target>coarsestresolution2
#  - surfacegeo<target>centerresolution
#  - surfacegeo<target>iauwestlongitude1
#  - surfacegeo<target>iauwestlongitude2
#  - surfacegeo<target>subsolariaulongitude
#  - surfacegeo<target>subobserveriaulongitude
#  - surfacegeo<target>observerlongitude1
#  - surfacegeo<target>observerlongitude2
#  - surfacegeo<target>centerphaseangle
#  - surfacegeo<target>phase1
#  - surfacegeo<target>phase2
#  - surfacegeo<target>incidence1
#  - surfacegeo<target>incidence2
#  - surfacegeo<target>emission1
#  - surfacegeo<target>emission2
#  - surfacegeo<target>solarhourangle1
#  - surfacegeo<target>solarhourangle2
#  - surfacegeo<target>planetocentriclatitude1
#  - surfacegeo<target>planetocentriclatitude2
#  - surfacegeo<target>subsolarplanetocentriclatitude
#  - surfacegeo<target>subobserverplanetocentriclatitude
#  - surfacegeo<target>planetographiclatitude1
#  - surfacegeo<target>planetographiclatitude2
#  - surfacegeo<target>subsolarplanetographiclatitude
#  - surfacegeo<target>subobserverplanetographiclatitude
#  - duration
#  - greaterpixelsize
#  - lesserpixelsize
#  - levels
#  - imagetype
#  - wavelength1
#  - wavelength2
#  - waveres1
#  - waveres2
#  - waveno1
#  - waveno2
#  - wavenores1
#  - wavenores2
#  - specflag
#  - specsize
#  - polarizationtype

# %% [markdown]
# ## Cassini VIMS shortcut
#
# In order to provide a more efficiant search on the Cassini VIMS database on OPUS, a shortcut on the `opus` cli command is available:

# %%
# Help on `cassini-vims`:
# !cassini-vims -h
# Out:
# usage: cassini-vims [-h] [-a] [-l LIMIT] [-p PAGE] [--field VALUE]
#                     [--cols COLS]
#                     TARGET_NAME
#
# Get Cassini VIMS Images and Cubes from OPUS API
#
# positional arguments:
#   TARGET_NAME           VIMS target name
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a, --all             Get all the output at once (disable: --limit/--page)
#   -l LIMIT, --limit LIMIT
#                         Output limits (default: 10)
#   -p PAGE, --page PAGE  Page offset (default: 1)
#   --field VALUE         Field key and value (sep. ` ` or `=`)
#   --cols COLS           Output columns (default:
#                         `opusid,target,revno,time1,primaryfilespec`)

# %%
# Make a query:
# !cassini-vims TITAN --timesec1 '2017-01-01' --timesec2 '2017-03-01' --channel IR --all
# Out:
# OPUS API Data objects (with 242 elements):
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862792312_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862792395_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862793872_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862793955_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862866150_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862866229_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862867642_1_IR
#  - COVIMS_0087-2017011T001031_2017012T075448-v1862867721_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1862976513_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1862976596_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1862978126_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1862978209_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1863062779_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1863063949_1_IR
#  - COVIMS_0087-2017012T081208_2017014T054632-v1863064054_1_IR
#  - COVIMS_0087-2017019T034314_2017021T045852-v1863666128_1_IR
#  - COVIMS_0087-2017019T034314_2017021T045852-v1863666211_1_IR
#  - COVIMS_0087-2017019T034314_2017021T045852-v1863667561_1_IR
#  - COVIMS_0087-2017019T034314_2017021T045852-v1863667644_1_IR
#  - COVIMS_0087-2017021T051652_2017022T123605-v1863751943_1_IR
#  - COVIMS_0087-2017021T051652_2017022T123605-v1863752026_1_IR
#  - COVIMS_0087-2017021T051652_2017022T123605-v1863753488_1_IR
#  - COVIMS_0087-2017021T051652_2017022T123605-v1863753571_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864353222_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864353351_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864355542_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864355671_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864356682_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864357007_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864357331_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864357655_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864357980_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864358304_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864358628_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864358953_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864359277_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864359601_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864359926_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864360250_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864360574_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864360899_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864361223_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864361547_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864361872_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864362196_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864362520_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864362845_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864363169_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864363493_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864363818_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864364142_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864364466_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864364791_1_IR
#  - COVIMS_0087-2017028T120637_2017029T060936-v1864365115_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864365439_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864365764_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864366088_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864366412_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864366737_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864367061_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864367385_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864367710_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864368034_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864368359_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864368683_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864369007_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864369332_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864369656_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864369980_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864370305_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864370629_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864370953_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864371278_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864371602_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864371926_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864372251_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864372575_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864372899_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864373224_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864373548_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864373872_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864374197_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864374521_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864374845_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864375170_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864375494_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864375818_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864376143_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864376467_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864376791_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864377116_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864377440_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864377764_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864378089_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864378413_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864378737_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864379062_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864379386_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864379710_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864380035_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864380359_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864380683_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864381008_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864381332_5_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864381872_5_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864381981_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864382305_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864382629_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864382954_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864383278_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864383602_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864383927_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864384251_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864384575_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864384900_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864385224_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864385548_1_IR
#  - COVIMS_0087-2017029T061501_2017029T115534-v1864385873_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864386197_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864386521_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864386846_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864387170_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864387494_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864387819_1_IR
#  - COVIMS_0087-2017029T120058_2017030T065828-v1864388143_5_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864632464_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864632787_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864633304_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864634153_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864634994_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864636084_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864648705_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864649692_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864650532_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864651357_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864652212_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864652661_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864655791_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864657571_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864658878_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864659548_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864661364_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864661731_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864663189_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864663519_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864664844_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864665211_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864666670_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864667904_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864668234_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864668451_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864668818_1_IR
#  - COVIMS_0087-2017031T165304_2017032T192717-v1864672184_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864672514_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864673033_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864673864_6_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864674712_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864676093_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864677247_6_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864678903_6_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864678967_6_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864679264_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864680254_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864681259_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864681709_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864682264_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864682759_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864683269_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864684304_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864685324_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864689209_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864690184_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864691152_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864694707_2_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864695532_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864696439_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864697265_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864698324_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864723859_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864724042_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864727564_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864727747_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864731124_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864731287_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864734684_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864734847_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864738124_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864738266_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864741224_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864741366_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864744193_2_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864745044_1_IR
#  - COVIMS_0087-2017032T193354_2017034T132303-v1864745262_4_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1865991585_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1865992312_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1865993107_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1865994012_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866002192_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866012565_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866013310_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866013982_3_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866014639_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866015293_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866018893_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866019913_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866023956_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866024976_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866030301_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866030565_1_IR
#  - COVIMS_0088-2017046T220936_2017048T130301-v1866031313_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866031973_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866032643_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866033308_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866038153_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866038438_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866042473_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866042758_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866044993_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866045781_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866046562_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866047341_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866048128_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866048893_3_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866050434_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866052073_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866052772_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866053618_3_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866054134_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866056558_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866057074_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866059416_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866060473_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866060973_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866062093_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866063293_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866064058_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866064861_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866065673_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866065979_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866068273_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866068557_1_IR
#  - COVIMS_0088-2017048T131401_2017050T022309-v1866070013_3_IR
