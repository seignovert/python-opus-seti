# %% [markdown]
# # Python package for OPUS-Seti API (NASA-PDS Rings Node) - CLI
#
# The `opus-seti` python package can be use directly in `python` (see [examples](https://nbviewer.jupyter.org/github/seignovert/python-opus-seti/blob/master/jupyter_notebooks/examples.ipynb)) but some the API can be called directly from the command line.
#
# Here is an examples of the few command line availables:
# - `opus`: Get data (global search)
# - `opus-meta`: Get detail for a single observation
# - `opus-preview`: Get image preview for a single observation
# - `opus-files`: Get files for a single observation
# - `opus-field`: Get information about field
#
# - `cassini-vims` Get data (shortcut to search only in the Cassini VIMS data)
#
# (__Note:__ To reproduce the examples, remove the initial `!` in the following lines.)

# %% [markdown]
# ## Getting data

# %%
# To get help on the main `opus` function:
# !opus -h
# Out:
# usage: opus [-h] [-a] [-l LIMIT] [-p PAGE] [--field VALUE]
#
# Get Data from OPUS-SETI API
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a, --all             Get all the output at once (disable: --limit/--page)
#   -l LIMIT, --limit LIMIT
#                         Output limits (default: 10)
#   -p PAGE, --page PAGE  Page offset (default: 1)
#   --field VALUE         Field key and value (sep. ` ` or `=`)

# %%
# Global OPUS query on the API:
# !opus -l 5 -p 2 --instrumentid='Cassini+VIMS' --typeid 'Image,Cube' --surfacegeometrytargetname TITAN
# Out:
# OPUS API Data objects (with 5 elements):
#  - S_CUBE_CO_VIMS_1463897465_IR
#  - S_CUBE_CO_VIMS_1463897481_IR
#  - S_CUBE_CO_VIMS_1463897514_IR
#  - S_CUBE_CO_VIMS_1463897558_VIS
#  - S_CUBE_CO_VIMS_1463905293_IR

# %% [markdown]
# ## Metadata

# %%
# Get the metada for a single observation:
# !opus-meta S_CUBE_CO_VIMS_1463887830_IR
# Out:
# OPUS API Metadata Ring observation: S_CUBE_CO_VIMS_1463887830_IR
#
# => GENERAL constraints
#  - is_image: False
#  - planet_id: SAT
#  - target_name: TITAN
#  - mission_id: CO
#  - inst_host_id: CO
#  - instrument_id: COVIMS
#  - time_sec1: 138510430.211
#  - time_sec2: 138510433.934
#  - time1: 2004-05-22 03:06:38.211000
#  - time2: 2004-05-22 03:06:41.934000
#  - target_class: MOON
#  - quantity: REFLECT
#  - type_id: CUBE
#  - ring_obs_id: S_CUBE_CO_VIMS_1463887830_IR
#  - right_asc1: 33.597013
#  - right_asc2: 33.781802
#  - declination1: 9.564464
#  - declination2: 9.746636
#  - observation_duration: 3.7229999899864197
#  - volume_id_list: COVIMS_0004
#  - primary_file_spec: COVIMS_0004/data/2004136T030633_2004143T032556/v1463887830_1.QUB
#
# => SATURN_SURFACE_GEOMETRY constraints
#  - sub_solar_planetocentric_latitude: -24.757
#  - sub_observer_planetocentric_latitude: -16.348
#  - sub_solar_planetographic_latitude: -29.543
#  - sub_observer_planetographic_latitude: -19.825
#  - sub_solar_IAU_longitude: 42.915
#  - sub_observer_IAU_longitude: 115.068
#  - center_resolution: 10610.0
#  - center_phase_angle: 67.361
#  - center_distance: 21435312.517
#
# => TITAN_SURFACE_GEOMETRY constraints
#  - sub_solar_planetocentric_latitude: -24.699
#  - sub_observer_planetocentric_latitude: -16.231
#  - sub_solar_planetographic_latitude: -24.699
#  - sub_observer_planetographic_latitude: -16.231
#  - sub_solar_IAU_longitude: 209.735
#  - sub_observer_IAU_longitude: 285.075
#  - center_resolution: 10753.0
#  - center_phase_angle: 70.272
#  - center_distance: 21722296.753
#
# => RING_GEOMETRY constraints
#  - ring_radius1: 1155776.141
#  - ring_radius2: 1269499.724
#  - resolution1: 10730.0
#  - resolution2: 10849.0
#  - projected_radial_resolution1: 14007.0
#  - projected_radial_resolution2: 19298.0
#  - range_to_ring_intercept1: 21675806.237
#  - range_to_ring_intercept2: 21917939.068
#  - ring_center_distance: 21435312.517
#  - J2000_longitude1: 317.627
#  - J2000_longitude2: 328.377
#  - solar_hour_angle1: 208.797
#  - solar_hour_angle2: 219.547
#  - longitude_WRT_observer1: 100.95
#  - longitude_WRT_observer2: 111.7
#  - ring_azimuth_WRT_observer1: 104.075
#  - ring_azimuth_WRT_observer2: 114.909
#  - sub_solar_ring_long: 288.83
#  - sub_observer_ring_long: 216.677
#  - solar_ring_elev1: -24.776
#  - solar_ring_elev2: -24.774
#  - observer_ring_elevation1: -16.162
#  - observer_ring_elevation2: -15.978
#  - phase1: 70.199
#  - phase2: 70.344
#  - incidence1: 65.224
#  - incidence2: 65.226
#  - emission1: 73.838
#  - emission2: 74.022
#  - north_based_incidence1: 114.774
#  - north_based_incidence2: 114.776
#  - north_based_emission1: 105.978
#  - north_based_emission2: 106.162
#  - ring_center_phase: 67.361
#  - ring_center_incidence: 65.243
#  - ring_center_emission: 73.652
#  - ring_center_north_based_incidence: 114.757
#  - ring_center_north_based_emission: 106.348
#  - solar_ring_opening_angle: -24.757
#  - observer_ring_opening_angle: -16.348
#  - edge_on_radius1: 1102060.665
#  - edge_on_radius2: 1170445.679
#  - edge_on_altitude1: -153111.275
#  - edge_on_altitude2: -81461.096
#  - edge_on_radial_resolution1: 10574.0
#  - edge_on_radial_resolution2: 10585.0
#  - range_to_edge_on_point1: 21361720.688
#  - range_to_edge_on_point2: 21383145.545
#  - edge_on_J2000_longitude1: 303.414
#  - edge_on_J2000_longitude2: 303.605
#  - edge_on_solar_hour_angle1: 194.584
#  - edge_on_solar_hour_angle2: 194.774
#
# => WAVELENGTH constraints
#  - wavelength1: 0.8842
#  - wavelength2: 5.1225
#  - spec_flag: Y
#  - wave_res1: 0.01662
#  - wave_res2: 0.01662
#  - wave_no1: 19.521717911176
#  - wave_no2: 113.09658448315
#  - wave_no_res1: 0.063338399547828
#  - wave_no_res2: 2.1258371794955
#  - spec_size: 96
#  - polarization_type: NONE
#
# => IMAGE constraints
#  - duration: 0.08
#  - image_type_id: RAST
#  - greater_pixel_size: 6.0
#  - lesser_pixel_size: 6.0
#  - levels: 4096
#
# => CASSINI_MISSION constraints
#  - cassini_target_name: Titan
#  - rev_no: 000
#  - obs_name: VIMS_000TI_LIGHTC065
#  - activity_name: LIGHTC
#  - spacecraft_clock_count1: 1463887830.223
#  - spacecraft_clock_count2: 1463887834.153
#  - prime: N
#
# => CASSINI_VIMS constraints
#  - channel: IR
#  - VIS_SAMPLING_MODE_ID: NORMAL
#  - IR_SAMPLING_MODE_ID: NORMAL
#  - VIS_EXPOSURE: 480.0
#  - IR_EXPOSURE: 80.0
#  - SPECTRAL_SUMMING: OFF
#  - SPECTRAL_EDITING: OFF
#  - INSTRUMENT_MODE_ID: IMAGE

# %% [markdown]
# ## Image previews

# %%
# Get the image preview for a single observation:
# !opus-preview -h
# Out:
# usage: opus-preview [-h] [-s {thumb,small,med,full}] [-d] [-o OUTPUT]
#                     ring_obs_id
#
# Get image for a single observation from OPUS-SETI API
#
# positional arguments:
#   ring_obs_id           Valid ring_obs_id
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -s {thumb,small,med,full}, --size {thumb,small,med,full}
#                         Image size
#   -d, --download        Download the image
#   -o OUTPUT, --output OUTPUT
#                         Output folder/filename for download

# %%
# Ex: get preview url location:
# !opus-preview S_CUBE_CO_VIMS_1463887830_IR -s med
# Out:
# https://pds-rings.seti.org/holdings/previews/COVIMS_0xxx/COVIMS_0004/data/2004136T030633_2004143T032556/v1463887830_1_med.png

# %%
# Ex: download preview:
# !opus-preview S_IMG_CO_ISS_1459551972_N -o ../tests/api/image/med/
# Out:
# ../tests/api/image/med/N1459551972_1_med.jpg

# %% [markdown]
# ## Image files

# %%
# Get files for a single observation:
# !opus-files -h
# Out:
# usage: opus-files [-h] [-f GROUP FORMAT] [-d] [-o OUTPUT] ring_obs_id
#
# Get files for a single observation from OPUS-SETI API
#
# positional arguments:
#   ring_obs_id           Valid ring_obs_id
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f GROUP FORMAT, --fmt GROUP FORMAT
#                         File format
#   -d, --download        Download the image
#   -o OUTPUT, --output OUTPUT
#                         Output folder/filename for download

# %%
# Ex: get file url location:
# !opus-files S_IMG_CO_ISS_1459551972_N
# Out:
# OPUS API Files for observation: S_IMG_CO_ISS_1459551972_N
#
# => RAW_IMAGE
#  - LBL: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1.LBL
#  - IMG: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1.IMG
#  - tlmtab: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/LABEL/TLMTAB.FMT
#  - prefix2: https://pds-rings.seti.org/holdings/volumes/COISS_2xxx/COISS_2001/LABEL/PREFIX2.FMT
#
# => CALIBRATED
#  - LBL: https://pds-rings.seti.org/holdings/calibrated/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_CALIB.LBL
#  - IMG: https://pds-rings.seti.org/holdings/calibrated/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_CALIB.IMG
#  - tlmtab: https://pds-rings.seti.org/holdings/calibrated/COISS_2xxx/COISS_2001/LABEL/TLMTAB.FMT
#  - prefix2: https://pds-rings.seti.org/holdings/calibrated/COISS_2xxx/COISS_2001/LABEL/PREFIX2.FMT
#
# => PREVIEWS
#  - full: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_full.jpg
#  - med: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_med.jpg
#  - small: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_small.jpg
#  - thumb: https://pds-rings.seti.org/holdings/previews/COISS_2xxx/COISS_2001/data/1459551663_1459568594/N1459551972_1_thumb.jpg

# %%
# Ex: download raw label file:
# !opus-files S_IMG_CO_ISS_1459551972_N -f RAW_IMAGE LBL -o ../tests/data/
# Out:
# ../tests/data/N1459551972_1.LBL

# %% [markdown]
# ## Getting information about fields

# %%
## Search for a known field
# !opus-field surfacegeometryTITANcenterdistance
# Out:
# Body Center Distance

# %%
# Get surface geometry for a specific target
# !opus-field TITAN
# Out:
# OPUS API Surface Geometry fields (31) for `Titan`:
#  - Sub-Solar IAU West Longitude (subsolarIAUlongitude)
#  - Finest Observed Resolution 2 (finestresolution2)
#  - Sub-Solar Planetocentric Latitude (subsolarplanetocentriclatitude)
#  - Sub-Observer Planetocentric Latitude (subobserverplanetocentriclatitude)
#  - Sub-Observer IAU West Longitude (subobserverIAUlongitude)
#  - D Observer Longitude (dObserverlongitude)
#  - Solar Hour Angle (solarhourangle)
#  - Finest Observed Resolution (finestresolution1)
#  - Observed Distance to Surface (rangetobody1)
#  - Observed Distance to Surface 2 (rangetobody2)
#  - Body Center Resolution (centerresolution)
#  - Sub-Solar Planetographic Latitude (subsolarplanetographiclatitude)
#  - D Solar Hour Angle (dsolarhourangle)
#  - Observed Planetographic Latitude (planetographiclatitude1)
#  - D Iau West Longitude (dIAUwestlongitude)
#  - Observed Planetographic Latitude 2 (planetographiclatitude2)
#  - Phase Angle at Body Center (centerphaseangle)
#  - Observed Local Time 2 (solarhourangle2)
#  - Coarsest Observed Resolution (coarsestresolution1)
#  - Coarsest Observed Resolution 2 (coarsestresolution2)
#  - Observed Planetocentric Latitude (planetocentriclatitude1)
#  - Observed Phase Angle 2 (phase2)
#  - Body Center Distance (centerdistance)
#  - Sub-Observer Planetographic Latitude (subobserverplanetographiclatitude)
#  - Observed Planetocentric Latitude 2 (planetocentriclatitude2)
#  - Observed Incidence Angle (incidence1)
#  - Observed Incidence Angle 2 (incidence2)
#  - Observed Phase Angle (phase1)
#  - Observed Emission Angle (emission1)
#  - Observed Emission Angle 2 (emission2)
#  - Observed Local Time (solarhourangle1)

# %%
# Get all the available fields/targets:
# !opus-field --all
# Out:
# OPUS API list of all fields available (304):
#  - GLOBAL
#  - JUPITER
#  - HYROKKIN
#  - CALLISTO
#  - CALLISTOIAU
#  - ROSALIND
#  - METHONE
#  - MIMASO
#  - ERRIAPUSIAU
#  - JULIET
#  - GALATEA
#  - IJIRAQ
#  - EPIMETHEUS
#  - EUROPA
#  - CRESSIDA
#  - SKATHI
#  - GREIP
#  - SUNO
#  - HIMALIA
#  - PAALIAQ
#  - CUPID
#  - TITANIA
#  - OBERON
#  - PLUTOO
#  - NIX
#  - PUCK
#  - ENCELADUS
#  - HYPERION
#  - NAIAD
#  - AMALTHEA
#  - CALLIRRHOEO
#  - LARISSA
#  - SUTTUNGR
#  - FORNJOT
#  - S132004
#  - PHOEBE
#  - HYDRAO
#  - THRYMR
#  - S122004
#  - SUN
#  - HYDRAIAU
#  - BERGELMIR
#  - PUCKIAU
#  - BELINDAO
#  - KARI
#  - DIONE
#  - DESPINA
#  - BELINDAIAU
#  - JANUS
#  - KIVIUQ
#  - CHARON
#  - TARQEQ
#  - KERBEROS
#  - HELENE
#  - PROMETHEUS
#  - AEGAEON
#  - PORTIA
#  - TETHYSO
#  - SKOLLO
#  - MIMASIAU
#  - TETHYS
#  - THEBE
#  - PLUTO
#  - PAN
#  - DESDEMONAO
#  - YMIRIAU
#  - IO
#  - DAPHNIS
#  - BELINDA
#  - OPHELIA
#  - ELARAIAU
#  - TITAN
#  - ARIEL
#  - PROTEUS
#  - NEPTUNE
#  - ANTHE
#  - ELARA
#  - STYX
#  - BESTLA
#  - SIARNAQ
#  - METIS
#  - RHEA
#  - NEREID
#  - IAPETUS
#  - KIVIUQIAU
#  - MAB
#  - ADRASTEA
#  - PANDORA
#  - SURTUR
#  - MIMAS
#  - TARVOS
#  - PANIAU
#  - ERRIAPUS
#  - SKOLL
#  - CALLISTOO
#  - PALLENEIAU
#  - SKOLLIAU
#  - UMBRIEL
#  - CALLIRRHOE
#  - THRYMRO
#  - HATI
#  - GREIPIAU
#  - EARTH
#  - TELESTO
#  - IOIAU
#  - BIANCA
#  - KARIO
#  - CORDELIA
#  - THALASSA
#  - TRITON
#  - URANUSO
#  - URANUS
#  - YMIR
#  - ALBIORIX
#  - BIANCAIAU
#  - SATURN
#  - CALYPSO
#  - THEBEIAU
#  - METISIAU
#  - MUNDILFARI
#  - TELESTOIAU
#  - JARNSAXAIAU
#  - PROMETHEUSIAU
#  - BESTLAO
#  - MIRANDA
#  - ATLAS
#  - POLYDEUCES
#  - PALLENE
#  - LOGE
#  - SIARNAQIAU
#  - GANYMEDE
#  - PAALIAQIAU
#  - PERDITA
#  - OPHELIAO
#  - S132004O
#  - DESDEMONA
#  - HYDRA
#  - NAIADIAU
#  - THALASSAO
#  - HATIIAU
#  - BEBHIONN
#  - RHEAO
#  - MIRANDAIAU
#  - CALYPSOIAU
#  - MABIAU
#  - BEBHIONNO
#  - ENCELADUSIAU
#  - EUROPAIAU
#  - SUNIAU
#  - MIRANDAO
#  - PAALIAQO
#  - THRYMRIAU
#  - PALLENEO
#  - JARNSAXA
#  - LOGEO
#  - NARVI
#  - ANTHEO
#  - NEPTUNEIAU
#  - PORTIAIAU
#  - IAPETUSO
#  - HYPERIONO
#  - HATIO
#  - PANO
#  - LARISSAO
#  - CUPIDIAU
#  - GALATEAO
#  - CHARONO
#  - BEBHIONNIAU
#  - EUROPAO
#  - PHOEBEO
#  - PERDITAO
#  - NEREIDO
#  - NARVIIAU
#  - CRESSIDAIAU
#  - TRITONIAU
#  - HELENEO
#  - TITANIAO
#  - EPIMETHEUSO
#  - KIVIUQO
#  - HYROKKINIAU
#  - S122004IAU
#  - BIANCAO
#  - NEPTUNEO
#  - ADRASTEAIAU
#  - EARTHO
#  - GANYMEDEIAU
#  - POLYDEUCESIAU
#  - UMBRIELO
#  - ENCELADUSO
#  - SIARNAQO
#  - PANDORAIAU
#  - UMBRIELIAU
#  - PROMETHEUSO
#  - TARVOSIAU
#  - TARQEQIAU
#  - TITANIAU
#  - GALATEAIAU
#  - LOGEIAU
#  - ARIELIAU
#  - ELARAO
#  - MUNDILFARIIAU
#  - TARVOSO
#  - JUPITERIAU
#  - TETHYSIAU
#  - GANYMEDEO
#  - NEREIDIAU
#  - SURTURIAU
#  - CALLIRRHOEIAU
#  - METISO
#  - DIONEO
#  - NIXIAU
#  - PLUTOIAU
#  - KERBEROSIAU
#  - KERBEROSO
#  - FORNJOTO
#  - ALBIORIXO
#  - S132004IAU
#  - SKATHIO
#  - SKATHIIAU
#  - PERDITAIAU
#  - DESPINAO
#  - SUTTUNGRIAU
#  - CALYPSOO
#  - TARQEQO
#  - THALASSAIAU
#  - ROSALINDIAU
#  - JULIETIAU
#  - NIXO
#  - SATURNO
#  - METHONEO
#  - HYROKKINO
#  - ANTHEIAU
#  - URANUSIAU
#  - DIONEIAU
#  - IJIRAQIAU
#  - PUCKO
#  - ADRASTEAO
#  - GREIPO
#  - IOO
#  - STYXO
#  - AEGAEONO
#  - AEGAEONIAU
#  - PROTEUSIAU
#  - LARISSAIAU
#  - DESPINAIAU
#  - POLYDEUCESO
#  - STYXIAU
#  - OBERONO
#  - OPHELIAIAU
#  - JANUSO
#  - HIMALIAIAU
#  - PHOEBEIAU
#  - PANDORAO
#  - CUPIDO
#  - EPIMETHEUSIAU
#  - TRITONO
#  - S122004O
#  - CORDELIAO
#  - DESDEMONAIAU
#  - OBERONIAU
#  - MUNDILFARIO
#  - ROSALINDO
#  - THEBEO
#  - BERGELMIRIAU
#  - TELESTOO
#  - METHONEIAU
#  - FORNJOTIAU
#  - PROTEUSO
#  - JANUSIAU
#  - AMALTHEAO
#  - DAPHNISO
#  - CORDELIAIAU
#  - KARIIAU
#  - SUTTUNGRO
#  - EARTHIAU
#  - HIMALIAO
#  - HYPERIONIAU
#  - TITANIAIAU
#  - NAIADO
#  - ALBIORIXIAU
#  - CRESSIDAO
#  - SURTURO
#  - AMALTHEAIAU
#  - RHEAIAU
#  - JARNSAXAO
#  - YMIRO
#  - JULIETO
#  - IJIRAQO
#  - ERRIAPUSO
#  - DAPHNISIAU
#  - BERGELMIRO
#  - IAPETUSIAU
#  - CHARONIAU
#  - NARVIO
#  - PORTIAO
#  - SATURNIAU
#  - MABO
#  - ATLASIAU
#  - ATLASO
#  - TITANO
#  - HELENEIAU
#  - ARIELO
#  - JUPITERO
#  - BESTLAIAU

# %% [markdown]
# ## Cassini VIMS shortcut
#
# In order to provide a more efficiant search on the Cassini VIMS database on OPUS, a shortcut on the `opus` cli command is available:

# %%
# Help on `cassini-vims`:
# !cassini-vims -h
# Out:
# usage: cassini-vims [-h] [-a] [-l LIMIT] [-p PAGE] [--field VALUE]
#                     [--cols COLS]
#                     TARGET_NAME
#
# Get Cassini VIMS Images and Cubes from OPUS API
#
# positional arguments:
#   TARGET_NAME           VIMS target name
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a, --all             Get all the output at once (disable: --limit/--page)
#   -l LIMIT, --limit LIMIT
#                         Output limits (default: 10)
#   -p PAGE, --page PAGE  Page offset (default: 1)
#   --field VALUE         Field key and value (sep. ` ` or `=`)
#   --cols COLS           Output columns (default: `ringobsid,target,revno,time1
#                         ,primaryfilespec,channel`)

# %%
# Make a query:
# !cassini-vims TITAN --timesec1 '2017-01-01' --timesec2 '2017-03-01' --channel IR --all
# Out:
# OPUS API Data objects (with 154 elements):
#  - S_CUBE_CO_VIMS_1862790782_IR
#  - S_CUBE_CO_VIMS_1862790865_IR
#  - S_CUBE_CO_VIMS_1862792312_IR
#  - S_CUBE_CO_VIMS_1862792395_IR
#  - S_CUBE_CO_VIMS_1862793872_IR
#  - S_CUBE_CO_VIMS_1862793955_IR
#  - S_CUBE_CO_VIMS_1862864590_IR
#  - S_CUBE_CO_VIMS_1862864669_IR
#  - S_CUBE_CO_VIMS_1862866150_IR
#  - S_CUBE_CO_VIMS_1862866229_IR
#  - S_CUBE_CO_VIMS_1862867642_IR
#  - S_CUBE_CO_VIMS_1862867721_IR
#  - S_CUBE_CO_VIMS_1862974938_IR
#  - S_CUBE_CO_VIMS_1862975021_IR
#  - S_CUBE_CO_VIMS_1862976513_IR
#  - S_CUBE_CO_VIMS_1862976596_IR
#  - S_CUBE_CO_VIMS_1862978126_IR
#  - S_CUBE_CO_VIMS_1862978209_IR
#  - S_CUBE_CO_VIMS_1863061384_IR
#  - S_CUBE_CO_VIMS_1863061489_IR
#  - S_CUBE_CO_VIMS_1863062779_IR
#  - S_CUBE_CO_VIMS_1863063949_IR
#  - S_CUBE_CO_VIMS_1863064054_IR
#  - S_CUBE_CO_VIMS_1863664613_IR
#  - S_CUBE_CO_VIMS_1863664696_IR
#  - S_CUBE_CO_VIMS_1863666128_IR
#  - S_CUBE_CO_VIMS_1863666211_IR
#  - S_CUBE_CO_VIMS_1863667561_IR
#  - S_CUBE_CO_VIMS_1863667644_IR
#  - S_CUBE_CO_VIMS_1863750443_IR
#  - S_CUBE_CO_VIMS_1863750526_IR
#  - S_CUBE_CO_VIMS_1863751943_IR
#  - S_CUBE_CO_VIMS_1863752026_IR
#  - S_CUBE_CO_VIMS_1863753488_IR
#  - S_CUBE_CO_VIMS_1863753571_IR
#  - S_CUBE_CO_VIMS_1864353222_IR
#  - S_CUBE_CO_VIMS_1864353351_IR
#  - S_CUBE_CO_VIMS_1864355542_IR
#  - S_CUBE_CO_VIMS_1864355671_IR
#  - S_CUBE_CO_VIMS_1864632464_IR
#  - S_CUBE_CO_VIMS_1864632787_IR
#  - S_CUBE_CO_VIMS_1864633304_IR
#  - S_CUBE_CO_VIMS_1864634153_IR
#  - S_CUBE_CO_VIMS_1864634994_IR
#  - S_CUBE_CO_VIMS_1864636084_IR
#  - S_CUBE_CO_VIMS_1864648705_IR
#  - S_CUBE_CO_VIMS_1864649692_IR
#  - S_CUBE_CO_VIMS_1864650532_IR
#  - S_CUBE_CO_VIMS_1864651357_IR
#  - S_CUBE_CO_VIMS_1864652212_IR
#  - S_CUBE_CO_VIMS_1864652661_IR
#  - S_CUBE_CO_VIMS_1864655344_IR
#  - S_CUBE_CO_VIMS_1864655791_IR
#  - S_CUBE_CO_VIMS_1864657571_IR
#  - S_CUBE_CO_VIMS_1864658878_IR
#  - S_CUBE_CO_VIMS_1864659548_IR
#  - S_CUBE_CO_VIMS_1864661364_IR
#  - S_CUBE_CO_VIMS_1864661731_IR
#  - S_CUBE_CO_VIMS_1864663189_IR
#  - S_CUBE_CO_VIMS_1864663519_IR
#  - S_CUBE_CO_VIMS_1864664844_IR
#  - S_CUBE_CO_VIMS_1864665211_IR
#  - S_CUBE_CO_VIMS_1864666670_IR
#  - S_CUBE_CO_VIMS_1864667904_IR
#  - S_CUBE_CO_VIMS_1864668234_IR
#  - S_CUBE_CO_VIMS_1864668451_IR
#  - S_CUBE_CO_VIMS_1864668818_IR
#  - S_CUBE_CO_VIMS_1864672184_IR
#  - S_CUBE_CO_VIMS_1864672514_IR
#  - S_CUBE_CO_VIMS_1864673033_IR
#  - S_CUBE_CO_VIMS_1864674712_IR
#  - S_CUBE_CO_VIMS_1864676093_IR
#  - S_CUBE_CO_VIMS_1864678967_IR
#  - S_CUBE_CO_VIMS_1864679264_IR
#  - S_CUBE_CO_VIMS_1864680254_IR
#  - S_CUBE_CO_VIMS_1864681259_IR
#  - S_CUBE_CO_VIMS_1864681709_IR
#  - S_CUBE_CO_VIMS_1864682264_IR
#  - S_CUBE_CO_VIMS_1864682759_IR
#  - S_CUBE_CO_VIMS_1864683269_IR
#  - S_CUBE_CO_VIMS_1864684304_IR
#  - S_CUBE_CO_VIMS_1864685324_IR
#  - S_CUBE_CO_VIMS_1864689209_IR
#  - S_CUBE_CO_VIMS_1864690184_IR
#  - S_CUBE_CO_VIMS_1864691152_IR
#  - S_CUBE_CO_VIMS_1864694707_IR
#  - S_CUBE_CO_VIMS_1864695532_IR
#  - S_CUBE_CO_VIMS_1864696439_IR
#  - S_CUBE_CO_VIMS_1864697265_IR
#  - S_CUBE_CO_VIMS_1864698324_IR
#  - S_CUBE_CO_VIMS_1864723859_IR
#  - S_CUBE_CO_VIMS_1864724042_IR
#  - S_CUBE_CO_VIMS_1864727564_IR
#  - S_CUBE_CO_VIMS_1864727747_IR
#  - S_CUBE_CO_VIMS_1864731124_IR
#  - S_CUBE_CO_VIMS_1864731287_IR
#  - S_CUBE_CO_VIMS_1864734684_IR
#  - S_CUBE_CO_VIMS_1864734847_IR
#  - S_CUBE_CO_VIMS_1864738124_IR
#  - S_CUBE_CO_VIMS_1864738266_IR
#  - S_CUBE_CO_VIMS_1864741224_IR
#  - S_CUBE_CO_VIMS_1864741366_IR
#  - S_CUBE_CO_VIMS_1864744193_IR
#  - S_CUBE_CO_VIMS_1864745044_IR
#  - S_CUBE_CO_VIMS_1864745262_IR
#  - S_CUBE_CO_VIMS_1865991585_IR
#  - S_CUBE_CO_VIMS_1865992312_IR
#  - S_CUBE_CO_VIMS_1865993107_IR
#  - S_CUBE_CO_VIMS_1865994012_IR
#  - S_CUBE_CO_VIMS_1866002192_IR
#  - S_CUBE_CO_VIMS_1866011812_IR
#  - S_CUBE_CO_VIMS_1866012565_IR
#  - S_CUBE_CO_VIMS_1866013310_IR
#  - S_CUBE_CO_VIMS_1866014639_IR
#  - S_CUBE_CO_VIMS_1866015293_IR
#  - S_CUBE_CO_VIMS_1866017777_IR
#  - S_CUBE_CO_VIMS_1866018893_IR
#  - S_CUBE_CO_VIMS_1866019913_IR
#  - S_CUBE_CO_VIMS_1866023956_IR
#  - S_CUBE_CO_VIMS_1866024976_IR
#  - S_CUBE_CO_VIMS_1866030301_IR
#  - S_CUBE_CO_VIMS_1866030565_IR
#  - S_CUBE_CO_VIMS_1866031313_IR
#  - S_CUBE_CO_VIMS_1866031973_IR
#  - S_CUBE_CO_VIMS_1866032643_IR
#  - S_CUBE_CO_VIMS_1866033308_IR
#  - S_CUBE_CO_VIMS_1866038153_IR
#  - S_CUBE_CO_VIMS_1866038438_IR
#  - S_CUBE_CO_VIMS_1866042473_IR
#  - S_CUBE_CO_VIMS_1866042758_IR
#  - S_CUBE_CO_VIMS_1866044993_IR
#  - S_CUBE_CO_VIMS_1866045781_IR
#  - S_CUBE_CO_VIMS_1866046562_IR
#  - S_CUBE_CO_VIMS_1866047341_IR
#  - S_CUBE_CO_VIMS_1866048128_IR
#  - S_CUBE_CO_VIMS_1866050434_IR
#  - S_CUBE_CO_VIMS_1866052073_IR
#  - S_CUBE_CO_VIMS_1866052772_IR
#  - S_CUBE_CO_VIMS_1866053618_IR
#  - S_CUBE_CO_VIMS_1866054134_IR
#  - S_CUBE_CO_VIMS_1866056558_IR
#  - S_CUBE_CO_VIMS_1866057074_IR
#  - S_CUBE_CO_VIMS_1866059416_IR
#  - S_CUBE_CO_VIMS_1866060473_IR
#  - S_CUBE_CO_VIMS_1866060973_IR
#  - S_CUBE_CO_VIMS_1866062093_IR
#  - S_CUBE_CO_VIMS_1866063293_IR
#  - S_CUBE_CO_VIMS_1866064058_IR
#  - S_CUBE_CO_VIMS_1866064861_IR
#  - S_CUBE_CO_VIMS_1866065673_IR
#  - S_CUBE_CO_VIMS_1866065979_IR
#  - S_CUBE_CO_VIMS_1866068273_IR
#  - S_CUBE_CO_VIMS_1866068557_IR
#  - S_CUBE_CO_VIMS_1866070013_IR
